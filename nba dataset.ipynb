# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df1 = pd.read_csvn1 = pd.read_csv(r'C:/Users/lenovo/Downloads/nba.csv')
df1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
s = df1.sort_values(by = 'Salary')

# %%
plt.plot(range(len(s)),s['Salary'])

# %%
l = list(df1['Height'])
d = {}
for i in range(len(l)):
    b = l[i].replace('-','.')
    d[b] = l[i]

# %%
def hg_data(data):
    for k,v in d.items():
        if data == v:
            return float(k)
df1['hgt'] = df1.Height.apply(hg_data)

# %%
df1.drop(columns = ['Height','College'],axis = 1,inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Weight    457 non-null    float64
#  6   Salary    446 non-null    float64
#  7   hgt       457 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 28.7+ KB

# %%
df1.describe()
# Out:
#            Number         Age      Weight        Salary         hgt
# count  457.000000  457.000000  457.000000  4.460000e+02  457.000000
# mean    17.678337   26.938731  221.522976  4.842684e+06    6.517133
# std     15.966090    4.404016   26.368343  5.229238e+06    0.352205
# min      0.000000   19.000000  161.000000  3.088800e+04    5.110000
# 25%      5.000000   24.000000  200.000000  1.044792e+06    6.110000
# 50%     13.000000   26.000000  220.000000  2.839073e+06    6.600000
# 75%     25.000000   30.000000  240.000000  6.500000e+06    6.800000
# max     99.000000   40.000000  307.000000  2.500000e+07    7.300000

# %%
df1.corr(numeric_only = True)
# Out:
#           Number       Age    Weight    Salary       hgt
# Number  1.000000  0.028724  0.206921 -0.112386  0.175314
# Age     0.028724  1.000000  0.087183  0.213459 -0.053471
# Weight  0.206921  0.087183  1.000000  0.138321  0.293000
# Salary -0.112386  0.213459  0.138321  1.000000 -0.035906
# hgt     0.175314 -0.053471  0.293000 -0.035906  1.000000

# %%
sns.heatmap(df1.corr(numeric_only = True),cmap =  'coolwarm',annot = True)
# Out:
# <Axes: >

# %%
df1['Salary'].fillna(df1['Salary'].median(),inplace = True)

# %%
plt.figure(figsize = (15,15))
axes = plt.subplot(3,2,1)
sns.boxplot(x = df1['Salary'])
plt.subplot(3,2,2)
sns.boxplot(x = df1['Age'])
plt.subplot(3,2,3)
sns.boxplot(x = df1['hgt'])
plt.subplot(3,2,4)
sns.boxplot(x = df1['Number'])
plt.subplot(3,2,5)
sns.boxplot(x = df1['Weight'])
# Out:
# <Axes: xlabel='Weight'>

# %%
plt.figure(figsize = (15,15))
axes = plt.subplot(3,2,1)
sns.distplot(x = df1['Salary'])
plt.xlabel('Salary')
plt.subplot(3,2,2)
# 
sns.distplot(x = df1['Age'],rug = True)
plt.xlabel('Age')
plt.subplot(3,2,3)

sns.distplot(x = df1['hgt'])
plt.xlabel('Height')

plt.subplot(3,2,4)
sns.distplot(x = df1['Number'])
plt.xlabel('Number')

plt.subplot(3,2,5)
sns.distplot(x = df1['Weight'])
plt.xlabel('Weight')
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\5058215.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = df1['Salary'])
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\5058215.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
print(f'Age Columns sknewness: {df1['Age'].skew()}')
print(f'Height Columns sknewness: {df1['hgt'].skew()}')
print(f'Weight Columns sknewness: {df1['Weight'].skew()}')
print(f'Salary Columns sknewness: {df1['Salary'].skew()}')
print(f'Number Columns sknewness: {df1['Number'].skew()}')
# Out:
# Age Columns sknewness: 0.6263487611614392
# Height Columns sknewness: -0.3155642842758824
# Weight Columns sknewness: 0.11378823248895656
# Salary Columns sknewness: 1.6137483312231116
# Number Columns sknewness: 1.6683863572180007

# %% [markdown]
# I have check the outlier in the data. i will  remove the outlier in the datase

# %%
q1 = np.percentile(df1['Salary'],25)
q3 = np.percentile(df1['Salary'],75)
iqr = q3 - q1

upper_sl = q3 + 1.5*iqr
lower_sl = q1 -  1.5*iqr
print("upper salary",upper_sl )
print("Lower salary",lower_sl)
# Out:
# upper salary 14177607.0
# Lower salary -6745601.0

# %%
q1 = np.percentile(df1['Age'],25)
q3 = np.percentile(df1['Age'],75)
iqr = q3 - q1

upper_ag = q3 + 1.5*iqr
lower_ag = q1 -  1.5*iqr
print("upper age",upper_ag)
print("Lower age",lower_ag)
# Out:
# upper age 39.0
# Lower age 15.0

# %%
q1 = np.percentile(df1['Weight'],25)
q3 = np.percentile(df1['Weight'],75)
iqr = q3 - q1

upper_wg = q3 + 1.5*iqr
lower_wg = q1 -  1.5*iqr
print("upper weight",upper_wg)
print("Lower weight",lower_wg)
# Out:
# upper weight 300.0
# Lower weight 140.0

# %%
q1 = np.percentile(df1['Number'],25)
q3 = np.percentile(df1['Number'],75)
iqr = q3 - q1

upper_nm = q3 + 1.5*iqr
lower_nm = q1 -  1.5*iqr
print("upper number",upper_nm)
print("Lower number",lower_nm)
# Out:
# upper number 55.0
# Lower number -25.0

# %%
q1 = np.percentile(df1['hgt'],25)
q3 = np.percentile(df1['hgt'],75)
iqr = q3 - q1

upper_hg = q3 + 1.5*iqr
lower_hg = q1 -  1.5*iqr
print("upper Height",upper_hg)
print("Lower Height",lower_hg)
# Out:
# upper Height 7.834999999999999
# Lower Height 5.075000000000001

# %%
df = df1[(df1["Salary"] < upper_sl) & (df1['Age'] > lower_ag) & (df1['Age'] < upper_ag) & (df1['Number'] < upper_nm) & (df1['Weight'] < upper_wg) & (df1['Weight'] > lower_wg) & (df1['hgt']>lower_hg) & (df1['hgt'] < upper_hg)]

# %%
df
# Out:
#               Name            Team  Number Position   Age  Weight     Salary  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0   180.0  7730337.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0   205.0  2839073.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0   185.0  1148640.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   231.0  5000000.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0   238.0  2165160.0
# ..             ...             ...     ...      ...   ...     ...        ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   234.0  2239800.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0   203.0  2433333.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0   179.0   900000.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0   256.0  2900000.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0   231.0   947276.0
#
#      hgt
# 0    6.2
# 2    6.5
# 3    6.5
# ...

# %%
plt.figure(figsize = (15,15))
axes = plt.subplot(3,2,1)
sns.boxplot(x = df['Salary'])
plt.subplot(3,2,2)
sns.boxplot(x = df['Age'])
plt.subplot(3,2,3)
sns.boxplot(x = df['hgt'])
plt.subplot(3,2,4)
sns.boxplot(x = df['Number'])
plt.subplot(3,2,5)
sns.boxplot(x = df['Weight'])
# Out:
# <Axes: xlabel='Weight'>

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary         hgt
# count  403.000000  403.000000  403.000000  4.030000e+02  403.000000
# mean    16.466501   26.729529  220.387097  3.605839e+06    6.522382
# std     13.278522    4.318628   26.014233  3.418066e+06    0.353713
# min      0.000000   19.000000  161.000000  3.088800e+04    5.110000
# 25%      5.000000   23.000000  200.000000  1.000000e+06    6.200000
# 50%     12.000000   26.000000  220.000000  2.500000e+06    6.600000
# 75%     25.000000   30.000000  240.000000  5.006780e+06    6.800000
# max     54.000000   38.000000  290.000000  1.400000e+07    7.300000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 403 entries, 0 to 456
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      403 non-null    object
#  1   Team      403 non-null    object
#  2   Number    403 non-null    float64
#  3   Position  403 non-null    object
#  4   Age       403 non-null    float64
#  5   Weight    403 non-null    float64
#  6   Salary    403 non-null    float64
#  7   hgt       403 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 28.3+ KB

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age  Weight     Salary  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0   180.0  7730337.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0   205.0  2839073.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0   185.0  1148640.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   231.0  5000000.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0   238.0  2165160.0
#
#    hgt
# 0  6.2
# 2  6.5
# 3  6.5
# 4  6.1
# 7  7.0

# %%
d =  df.sort_values(by = 'Salary')
sns.scatterplot(x = range(len(d)),y = d['Salary'],hue = d['Age'])
# Out:
# <Axes: ylabel='Salary'>

# %%
member = df.groupby('Team')['Name'].count().reset_index()
plt.figure(figsize = (15,6))
sns.barplot(x = 'Team',y = 'Name',data = member,palette = list('rgb'))
plt.xticks(rotation = 90)
plt.title('Player Count of Team Wise')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\3349497699.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Team',y = 'Name',data = member,palette = list('rgb'))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\3349497699.py:3: UserWarning:
# The palette list has fewer values (3) than needed (30) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x = 'Team',y = 'Name',data = member,palette = list('rgb'))

# %%
member = df.groupby('Team')['Salary'].mean().reset_index()
plt.figure(figsize = (15,6))
sns.barplot(x = 'Team',y = 'Salary',data = member,palette = list('rgb') )
plt.xticks(rotation = 90)
plt.title('Average Salary of Team Wise')
plt.ylabel('Average Salary')
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\1810763081.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Team',y = 'Salary',data = member,palette = list('rgb') )
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\1810763081.py:3: UserWarning:
# The palette list has fewer values (3) than needed (30) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x = 'Team',y = 'Salary',data = member,palette = list('rgb') )

# %%
print(f'Age Columns sknewness: {df['Age'].skew()}')
print(f'Height Columns sknewness: {df['hgt'].skew()}')
print(f'Weight Columns sknewness: {df['Weight'].skew()}')
print(f'Salary Columns sknewness: {df['Salary'].skew()}')
print(f'Number Columns sknewness: {df['Number'].skew()}')
# Out:
# Age Columns sknewness: 0.5274197610398281
# Height Columns sknewness: -0.3902300142374913
# Weight Columns sknewness: 0.11596441908853888
# Salary Columns sknewness: 1.3848349140608904
# Number Columns sknewness: 0.740109946161213

# %%
plt.figure(figsize = (15,15))
axes = plt.subplot(3,2,1)
sns.distplot(x = df['Salary'])
plt.xlabel('Salary')
plt.subplot(3,2,2)
# 
sns.distplot(x = df['Age'],rug = True)
plt.xlabel('Age')
plt.subplot(3,2,3)

sns.distplot(x = df['hgt'])
plt.xlabel('Height')

plt.subplot(3,2,4)
sns.distplot(x = df['Number'])
plt.xlabel('Number')

plt.subplot(3,2,5)
sns.distplot(x = df['Weight'])
plt.xlabel('Weight')
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\3586486194.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = df['Salary'])
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\3586486194.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
def age_cat(data):
    if data in range(19,26): return "Younger Player"
    elif data in range(26,32): return "Experience Player" 
    else: return "Senior Player"
df['Age_category'] = df['Age'].apply(age_cat)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\1445600513.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age_category'] = df['Age'].apply(age_cat)

# %%
# df.drop(columns = 'Age_category',axis = 1,inplace = True)

# %%
sal = df.groupby(df['Age_category'])['Salary'].mean().reset_index()
ax = sns.barplot(x = 'Age_category',y = 'Salary' , data = sal,palette = list('rgb'))
for i in range(sal.Salary.nunique()):
    ax.bar_label(ax.containers[i]) 
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\3879358343.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x = 'Age_category',y = 'Salary' , data = sal,palette = list('rgb'))

# %%
sal = df.groupby(df['Age_category'])['Weight'].mean().reset_index()
ax = sns.barplot(x = 'Age_category',y = 'Weight', data = sal,palette = list('rgb'))
for i in range(sal.Weight.nunique()):
    ax.bar_label(ax.containers[i])
plt.title('Average Weight Age Category')
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\1575481012.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x = 'Age_category',y = 'Weight', data = sal,palette = list('rgb'))

# %%
sal = df.groupby(df['Age_category'])['hgt'].mean().reset_index()
ax = sns.barplot(x = 'Age_category',y = 'hgt', data = sal,palette = list('rgb'))
for i in range(sal.hgt.nunique()):
    ax.bar_label(ax.containers[i])
plt.title('Average Height Age Category')
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\3358324888.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x = 'Age_category',y = 'hgt', data = sal,palette = list('rgb'))

# %%
def lbs_to_kg(lbs):
    return lbs / 2.20462
df['Weight_kg'] = df.Weight.apply(lbs_to_kg)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\1579211490.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight_kg'] = df.Weight.apply(lbs_to_kg)

# %%
wei = round(df.groupby(df['Position'])['Weight_kg'].mean().reset_index())
ax = sns.barplot(x = wei['Position'],y = wei['Weight_kg'],palette = list('rgb'))
for i in range(wei.Weight_kg.nunique()):
    ax.bar_label(ax.containers[i])
plt.title('Avgerage Weight by position')
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\4094482228.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x = wei['Position'],y = wei['Weight_kg'],palette = list('rgb'))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\4094482228.py:2: UserWarning:
# The palette list has fewer values (3) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x = wei['Position'],y = wei['Weight_kg'],palette = list('rgb'))

# %%
wei = round(df.groupby(df['Position'])['hgt'].mean().reset_index())
ax = sns.barplot(x = wei['Position'],y = wei['hgt'],palette = list('rgb'))
for i in range(len(wei.hgt)):
    ax.bar_label(ax.containers[i])
plt.title('Avgerage Height by position (in feet)')
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\1186296293.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x = wei['Position'],y = wei['hgt'],palette = list('rgb'))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18464\1186296293.py:2: UserWarning:
# The palette list has fewer values (3) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x = wei['Position'],y = wei['hgt'],palette = list('rgb'))

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age  Weight     Salary  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0   180.0  7730337.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0   205.0  2839073.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0   185.0  1148640.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   231.0  5000000.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0   238.0  2165160.0
#
#    hgt       Age_category   Weight_kg
# 0  6.2     Younger Player   81.646724
# 2  6.5  Experience Player   92.986546
# 3  6.5     Younger Player   83.914688
# 4  6.1  Experience Player  104.779962
# 7  7.0     Younger Player  107.955112

# %%
plt.figure(figsize = (15,6))
sal = df.groupby('Team')['Salary'].mean().reset_index()
sns.barplot(x = 'Team',y= 'Salary',data = sal,saturation = 0.20)
plt.xticks(rotation= 90)
plt.show()
